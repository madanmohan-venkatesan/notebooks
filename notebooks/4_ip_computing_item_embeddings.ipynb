# %%
import time

notebook_start_time = time.time()

# %% [markdown]
# # Set up environment

# %%
import sys
from pathlib import Path


def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False


def clone_repository() -> None:
    # !git clone https://github.com/decodingml/hands-on-recommender-system.git
    # %cd hands-on-recommender-system/


def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml


if is_google_colab():
    clone_repository()
    install_dependencies()

    root_dir = str(Path().absolute())
    print("⛳️ Google Colab environment")
else:
    root_dir = str(Path().absolute().parent)
    print("⛳️ Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    print(f"Adding the following directory to the PYTHONPATH: {root_dir}")
    sys.path.append(root_dir)
# Out:
# Streaming output truncated to the last 5000 lines.
# catboost   ------------------------------ 4.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.90 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.60 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.92 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.70 MiB/346.60 MiB
# tensorflow ------------------------------ 6.87 MiB/467.18 MiB
# ⠼ Preparing packages... (45/63)
# langchain  ------------------------------ 623.89 KiB/952.60 KiB
# jedi       ------------------------------ 720.00 KiB/1.50 MiB
# streamlit  ------------------------------ 5.92 MiB/8.04 MiB
# pandas     ------------------------------ 6.91 MiB/11.67 MiB
# botocore   ------------------------------ 6.03 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 6.84 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.81 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 7.06 MiB/53.70 MiB
# catboost   ------------------------------ 4.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.00 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.70 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.79 MiB/346.60 MiB
# tensorflow ------------------------------ 6.96 MiB/467.18 MiB
# ⠼ Preparing packages... (45/63)
# langchain  ------------------------------ 623.89 KiB/952.60 KiB
# jedi       ------------------------------ 768.00 KiB/1.50 MiB
# streamlit  ------------------------------ 6.11 MiB/8.04 MiB
# pandas     ------------------------------ 7.16 MiB/11.67 MiB
# botocore   ------------------------------ 6.11 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 7.09 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.90 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.93 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 7.30 MiB/53.70 MiB
# catboost   ------------------------------ 4.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.12 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.81 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.23 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.02 MiB/346.60 MiB
# tensorflow ------------------------------ 7.22 MiB/467.18 MiB
# ⠴ Preparing packages... (47/63)
# langchain  ------------------------------ 672.00 KiB/952.60 KiB
# jedi       ------------------------------ 783.78 KiB/1.50 MiB
# streamlit  ------------------------------ 6.34 MiB/8.04 MiB
# pandas     ------------------------------ 7.33 MiB/11.67 MiB
# botocore   ------------------------------ 6.33 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 7.22 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.16 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 7.24 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 7.53 MiB/53.70 MiB
# catboost   ------------------------------ 4.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.38 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 7.16 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.37 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.15 MiB/346.60 MiB
# tensorflow ------------------------------ 7.46 MiB/467.18 MiB
# ⠴ Preparing packages... (47/63)
# langchain  ------------------------------ 672.00 KiB/952.60 KiB
# jedi       ------------------------------ 799.78 KiB/1.50 MiB
# streamlit  ------------------------------ 6.38 MiB/8.04 MiB
# pandas     ------------------------------ 7.54 MiB/11.67 MiB
# botocore   ------------------------------ 6.38 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 7.55 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.49 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 7.47 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 7.78 MiB/53.70 MiB
# catboost   ------------------------------ 4.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.69 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 7.30 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.64 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7
MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.74 MiB/346.60 MiB
# tensorflow ------------------------------ 8.99 MiB/467.18 MiB
# ⠧ Preparing packages... (47/63)
# langchain  ------------------------------ 720.00 KiB/952.60 KiB
# jedi       ------------------------------ 928.00 KiB/1.50 MiB
# streamlit  ------------------------------ 7.34 MiB/8.04 MiB
# pandas     ------------------------------ 9.03 MiB/11.67 MiB
# botocore   ------------------------------ 7.14 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 8.98 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 8.83 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 8.88 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.26 MiB/53.70 MiB
# catboost   ------------------------------ 4.44 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.09 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.74 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.05 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 8.84 MiB/346.60 MiB
# tensorflow ------------------------------ 9.12 MiB/467.18 MiB
# ⠧ Preparing packages... (47/63)
# langchain  ------------------------------ 720.00 KiB/952.60 KiB
# jedi       ------------------------------ 928.00 KiB/1.50 MiB
# streamlit  ------------------------------ 7.49 MiB/8.04 MiB
# pandas     ------------------------------ 9.05 MiB/11.67 MiB
# botocore   ------------------------------ 7.16 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.14 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.05 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.11 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.38 MiB/53.70 MiB
# catboost   ------------------------------ 4.56 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.26 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 8.91 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.24 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.06 MiB/346.60 MiB
# tensorflow ------------------------------ 9.29 MiB/467.18 MiB
# ⠧ Preparing packages... (47/63)
# langchain  ------------------------------ 720.00 KiB/952.60 KiB
# jedi       ------------------------------ 928.00 KiB/1.50 MiB
# streamlit  ------------------------------ 7.71 MiB/8.04 MiB
# pandas     ------------------------------ 9.05 MiB/11.67 MiB
# botocore   ------------------------------ 7.19 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.33 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.17 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.23 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.56 MiB/53.70 MiB
# catboost   ------------------------------ 4.78 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.49 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.13 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.44 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.19 MiB/346.60 MiB
# tensorflow ------------------------------ 9.47 MiB/467.18 MiB
# ⠧ Preparing packages... (47/63)
# langchain  ------------------------------ 736.00 KiB/952.60 KiB
# jedi       ------------------------------ 944.00 KiB/1.50 MiB
# streamlit  ------------------------------ 7.87 MiB/8.04 MiB
# pandas     ------------------------------ 9.17 MiB/11.67 MiB
# botocore   ------------------------------ 7.58 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.50 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.36 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.41 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.71 MiB/53.70 MiB
# catboost   ------------------------------ 4.95 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.65 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.28 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.62 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.36 MiB/346.60 MiB
# tensorflow ------------------------------ 9.59 MiB/467.18 MiB
# ⠇ Preparing packages... (47/63)
# langchain  ------------------------------ 752.00 KiB/952.60 KiB
# jedi       ------------------------------ 976.00 KiB/1.50 MiB
# streamlit  ------------------------------ 7.94 MiB/8.04 MiB
# pandas     ------------------------------ 9.27 MiB/11.67 MiB
# botocore   ------------------------------ 7.92 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.73 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.58 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.62 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 9.92 MiB/53.70 MiB
# catboost   ------------------------------ 5.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 9.84 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.40 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 9.75 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.51 MiB/346.60 MiB
# tensorflow ------------------------------ 9.74 MiB/467.18 MiB
# ⠇ Preparing packages... (47/63)
# langchain  ------------------------------ 768.00 KiB/952.60 KiB
# jedi       ------------------------------ 992.00 KiB/1.50 MiB
# pandas     ------------------------------ 9.39 MiB/11.67 MiB
# botocore   ------------------------------ 8.00 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.90 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.78 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.83 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.08 MiB/53.70 MiB
# catboost   ------------------------------ 5.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.01 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.63 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.00 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.73 MiB/346.60 MiB
# tensorflow ------------------------------ 9.97 MiB/467.18 MiB
# ⠇ Preparing packages... (47/63)
# langchain  ------------------------------ 768.00 KiB/952.60 KiB
# jedi       ------------------------------ 992.00 KiB/1.50 MiB
# pandas     ------------------------------ 9.41 MiB/11.67 MiB
# botocore   ------------------------------ 8.00 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 9.90 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.78 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 9.83 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.08 MiB/53.70 MiB
# catboost   ------------------------------ 5.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.01 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.63 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.00 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.73 MiB/346.60 MiB
# tensorflow ------------------------------ 9.97 MiB/467.18 MiB
# ⠇ Preparing packages... (47/63)
# langchain  ------------------------------ 784.00 KiB/952.60 KiB
# jedi       ------------------------------ 1008.00 KiB/1.50 MiB
# pandas     ------------------------------ 9.45 MiB/11.67 MiB
# botocore   ------------------------------ 8.42 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.07 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 9.94 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.00 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.24 MiB/53.70 MiB
# catboost   ------------------------------ 5.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.18 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.80 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.17 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 9.89 MiB/346.60 MiB
# tensorflow ------------------------------ 10.15 MiB/467.18 MiB
# ⠇ Preparing packages... (47/63)
# langchain  ------------------------------ 784.00 KiB/952.60 KiB
# jedi       ------------------------------ 1.04 MiB/1.50 MiB
# pandas     ------------------------------ 9.45 MiB/11.67 MiB
# botocore   ------------------------------ 8.72 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.23 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.09 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.15 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.41 MiB/53.70 MiB
# catboost   ------------------------------ 5.00 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.32 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.94 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.29 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.03 MiB/346.60 MiB
# tensorflow ------------------------------ 10.30 MiB/467.18 MiB
# ⠇ Preparing packages... (47/63)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# pandas     ------------------------------ 9.50 MiB/11.67 MiB
# botocore   ------------------------------ 9.02 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.25 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.15 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.18 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.44 MiB/53.70 MiB
# catboost   ------------------------------ 5.03 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.38 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 9.99 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.33 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.06 MiB/346.60 MiB
# tensorflow ------------------------------ 10.33 MiB/467.18 MiB
# ⠋ Preparing packages... (49/63)
# jedi       ------------------------------ 1.07 MiB/1.50 MiB
# pandas     ------------------------------ 9.53 MiB/11.67 MiB
# botocore   ------------------------------ 9.04 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.39 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.30 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.31 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.57 MiB/53.70 MiB
# catboost   ------------------------------ 5.17 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.54 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.13 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.47 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.20 MiB/346.60 MiB
# tensorflow ------------------------------ 10.49 MiB/467.18 MiB
# ⠋ Preparing packages... (49/63)
# jedi       ------------------------------ 1.09 MiB/1.50 MiB
# pandas     ------------------------------ 9.64 MiB/11.67 MiB
# botocore   ------------------------------ 9.21 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.68 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.48 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.57 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 10.79 MiB/53.70 MiB
# catboost   ------------------------------ 5.38 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 10.74 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.41 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.70 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.50 MiB/346.60 MiB
# tensorflow ------------------------------ 10.74 MiB/467.18 MiB
# ⠋ Preparing packages... (49/63)
# jedi       ------------------------------ 1.09 MiB/1.50 MiB
# pandas     ------------------------------ 9.73 MiB/11.67 MiB
# botocore   ------------------------------ 9.32 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 10.90 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.78 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 10.79 MiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------ 11.07 MiB/53.70 MiB
# catboost   ------------------------------ 5.67 MiB/93.98 MiB
# nvidia-cusolver-cu12 ------------------------------ 11.04 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 10.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 10.90 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 10.66 MiB/346.60 MiB
# tensorflow ------------------------------ 10.99 MiB/467.18 MiB
# ⠋ Preparing packages... (49/63)
# jedi       ------------------------------ 1.13 MiB/1.50 MiB
# pandas     ------------------------------ 9.85 MiB/11.67 MiB
# botocore   ------------------------------ 9.86 MiB/12.74 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 11.09 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 10.95 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 11
# catboost   ------------------------------ 93.00 MiB/93.98 MiB
# tensorflow ------------------------------ 405.77 MiB/467.18 MiB
# ⠙ Preparing packages... (60/63)
# catboost   ------------------------------ 93.00 MiB/93.98 MiB
# tensorflow ------------------------------ 406.93 MiB/467.18 MiB
# ⠹ Preparing packages... (60/63)
# catboost   ------------------------------ 93.00 MiB/93.98 MiB
# tensorflow ------------------------------ 408.09 MiB/467.18 MiB
# ⠹ Preparing packages... (60/63)
# catboost   ------------------------------ 93.00 MiB/93.98 MiB
# tensorflow ------------------------------ 408.28 MiB/467.18 MiB
# ⠹ Preparing packages... (60/63)
# catboost   ------------------------------ 93.00 MiB/93.98 MiB
# tensorflow ------------------------------ 408.59 MiB/467.18 MiB
# ⠹ Preparing packages... (60/63)
# catboost   ------------------------------ 93.00 MiB/93.98 MiB
# tensorflow ------------------------------ 408.83 MiB/467.18 MiB
# ⠸ Preparing packages... (60/63)
# tensorflow ------------------------------ 408.84 MiB/467.18 MiB
# ⠸ Preparing packages... (60/63)
# tensorflow ------------------------------ 410.17 MiB/467.18 MiB
# ⠸ Preparing packages... (60/63)
# tensorflow ------------------------------ 410.80 MiB/467.18 MiB
# ⠸ Preparing packages... (60/63)
# tensorflow ------------------------------ 411.73 MiB/467.18 MiB
# ⠸ Preparing packages... (60/63)
# tensorflow ------------------------------ 411.76 MiB/467.18 MiB
# ⠼ Preparing packages... (61/63)
# tensorflow ------------------------------ 411.79 MiB/467.18 MiB
# ⠼ Preparing packages... (61/63)
# tensorflow ------------------------------ 411.87 MiB/467.18 MiB
# ⠼ Preparing packages... (61/63)
# tensorflow ------------------------------ 412.17 MiB/467.18 MiB
# ⠼ Preparing packages... (61/63)
# tensorflow ------------------------------ 412.94 MiB/467.18 MiB
# ⠴ Preparing packages... (61/63)
# tensorflow ------------------------------ 413.19 MiB/467.18 MiB
# ⠴ Preparing packages... (61/63)
# tensorflow ------------------------------ 413.53 MiB/467.18 MiB
# ⠴ Preparing packages... (61/63)
# tensorflow ------------------------------ 413.58 MiB/467.18 MiB
# ⠴ Preparing packages... (61/63)
# tensorflow ------------------------------ 414.22 MiB/467.18 MiB
# ⠦ Preparing packages... (61/63)
# tensorflow ------------------------------ 414.44 MiB/467.18 MiB
# ⠦ Preparing packages... (61/63)
# tensorflow ------------------------------ 414.66 MiB/467.18 MiB
# ⠦ Preparing packages... (61/63)
# tensorflow ------------------------------ 414.88 MiB/467.18 MiB
# ⠦ Preparing packages... (61/63)
# tensorflow ------------------------------ 414.98 MiB/467.18 MiB
# ⠧ Preparing packages... (61/63)
# tensorflow ------------------------------ 415.58 MiB/467.18 MiB
# ⠧ Preparing packages... (61/63)
# tensorflow ------------------------------ 415.81 MiB/467.18 MiB
# ⠧ Preparing packages... (61/63)
# tensorflow ------------------------------ 416.02 MiB/467.18 MiB
# ⠧ Preparing packages... (61/63)
# tensorflow ------------------------------ 416.15 MiB/467.18 MiB
# ⠇ Preparing packages... (61/63)
# tensorflow ------------------------------ 416.67 MiB/467.18 MiB
# ⠇ Preparing packages... (61/63)
# tensorflow ------------------------------ 416.82 MiB/467.18 MiB
# ⠇ Preparing packages... (61/63)
# tensorflow ------------------------------ 417.12 MiB/467.18 MiB
# ⠇ Preparing packages... (61/63)
# tensorflow ------------------------------ 417.30 MiB/467.18 MiB
# ⠋ Preparing packages... (61/63)
# tensorflow ------------------------------ 417.56 MiB/467.18 MiB
# ⠋ Preparing packages... (61/63)
# tensorflow ------------------------------ 417.94 MiB/467.18 MiB
# ⠋ Preparing packages... (61/63)
# tensorflow ------------------------------ 418.31 MiB/467.18 MiB
# ⠋ Preparing packages... (61/63)
# tensorflow ------------------------------ 418.53 MiB/467.18 MiB
# ⠙ Preparing packages... (61/63)
# tensorflow ------------------------------ 418.72 MiB/467.18 MiB
# ⠙ Preparing packages... (61/63)
# tensorflow ------------------------------ 418.88 MiB/467.18 MiB
# ⠙ Preparing packages... (61/63)
# tensorflow ------------------------------ 419.00 MiB/467.18 MiB
# ⠙ Preparing packages... (61/63)
# tensorflow ------------------------------ 419.27 MiB/467.18 MiB
# ⠹ Preparing packages... (61/63)
# tensorflow ------------------------------ 419.59 MiB/467.18 MiB
# ⠹ Preparing packages... (61/63)
# tensorflow ------------------------------ 419.86 MiB/467.18 MiB
# ⠹ Preparing packages... (61/63)
# tensorflow ------------------------------ 420.17 MiB/467.18 MiB
# ⠹ Preparing packages... (61/63)
# tensorflow ------------------------------ 420.44 MiB/467.18 MiB
# ⠸ Preparing packages... (61/63)
# tensorflow ------------------------------ 420.60 MiB/467.18 MiB
# ⠸ Preparing packages... (61/63)
# tensorflow ------------------------------ 421.32 MiB/467.18 MiB
# ⠸ Preparing packages... (61/63)
# tensorflow ------------------------------ 421.60 MiB/467.18 MiB
# ⠸ Preparing packages... (61/63)
# tensorflow ------------------------------ 421.76 MiB/467.18 MiB
# ⠼ Preparing packages... (61/63)
# tensorflow ------------------------------ 421.94 MiB/467.18 MiB
# ⠼ Preparing packages... (61/63)
# tensorflow ------------------------------ 422.00 MiB/467.18 MiB
# ⠼ Preparing packages... (61/63)
# tensorflow ------------------------------ 422.04 MiB/467.18 MiB
# ⠼ Preparing packages... (61/63)
# tensorflow ------------------------------ 422.19 MiB/467.18 MiB
# ⠴ Preparing packages... (61/63)
# tensorflow ------------------------------ 422.22 MiB/467.18 MiB
# ⠴ Preparing packages... (61/63)
# tensorflow ------------------------------ 422.22 MiB/467.18 MiB
# ⠴ Preparing packages... (61/63)
# tensorflow ------------------------------ 422.30 MiB/467.18 MiB
# ⠴ Preparing packages... (61/63)
# tensorflow ------------------------------ 422.87 MiB/467.18 MiB
# ⠦ Preparing packages... (61/63)
# tensorflow ------------------------------ 422.98 MiB/467.18 MiB
# ⠦ Preparing packages... (61/63)
# tensorflow ------------------------------ 423.10 MiB/467.18 MiB
# ⠦ Preparing packages... (61/63)
# tensorflow ------------------------------ 423.43 MiB/467.18 MiB
# ⠦ Preparing packages... (61/63)
# tensorflow ------------------------------ 423.60 MiB/467.18 MiB
# ⠧ Preparing packages... (61/63)
# tensorflow ------------------------------ 423.73 MiB/467.18 MiB
# ⠧ Preparing packages... (61/63)
# tensorflow ------------------------------ 423.84 MiB/467.18 MiB
# ⠧ Preparing packages... (61/63)
# tensorflow ------------------------------ 423.87 MiB/467.18 MiB
# ⠧ Preparing packages... (61/63)
# tensorflow ------------------------------ 423.88 MiB/467.18 MiB
# ⠇ Preparing packages... (61/63)
# tensorflow ------------------------------ 424.58 MiB/467.18 MiB
# ⠇ Preparing packages... (61/63)
# tensorflow ------------------------------ 425.15 MiB/467.18 MiB
# ⠇ Preparing packages... (61/63)
# ⠇ Preparing packages... (61/63)
# ⠇ Preparing packages... (61/63)
# ⠋ Preparing packages... (62/63)
# ⠋ Preparing packages... (62/63)
# ⠋ Preparing packages... (62/63)
# ⠋ Preparing packages... (62/63)
# ⠙ Preparing packages... (62/63)
# ⠙ Preparing packages... (62/63)
# ⠙ Preparing packages... (62/63)
# ⠙ Preparing packages... (62/63)
# ⠹ Preparing packages... (62/63)
# ⠹ Preparing packages... (62/63)
# ⠹ Preparing packages... (62/63)
# ⠹ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠴ Preparing packages... (62/63)
# ⠴ Preparing packages... (62/63)
# ⠴ Preparing packages... (62/63)
# ⠴ Preparing packages... (62/63)
# ⠦ Preparing packages... (62/63)
# ⠦ Preparing packages... (62/63)
# ⠦ Preparing packages... (62/63)
# ⠦ Preparing packages... (62/63)
# ⠧ Preparing packages... (62/63)
# ⠧ Preparing packages... (62/63)
# ⠧ Preparing packages... (62/63)
# ⠇ Preparing packages... (62/63)
# ⠇ Preparing packages... (62/63)
# ⠇ Preparing packages... (62/63)
# ⠇ Preparing packages... (62/63)
# ⠇ Preparing packages... (62/63)
# ⠋ Preparing packages... (62/63)
# ⠋ Preparing packages... (62/63)
# ⠋ Preparing packages... (62/63)
# ⠋ Preparing packages... (62/63)
# ⠙ Preparing packages... (62/63)
# ⠙ Preparing packages... (62/63)
# ⠙ Preparing packages... (62/63)
# ⠙ Preparing packages... (62/63)
# ⠹ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠸ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠼ Preparing packages... (62/63)
# ⠴ Preparing packages... (62/63)
# ⠴ Preparing packages... (62/63)
# ⠴ Preparing packages... (62/63)
# ⠴ Preparing packages... (62/63)
# ⠦ Preparing packages... (62/63)
# ⠦ Preparing packages... (62/63)
# ⠦ Preparing packages... (62/63)
# ⠦ Preparing packages... (62/63)
# ⠧ Preparing packages... (62/63)
# ⠧ Preparing packages... (62/63)
# ⠧ Preparing packages... (62/63)
# ⠧ Preparing packages... (62/63)
# Prepared 63 packages in 51.90s
# Uninstalled 29 packages in 2.00s
# Installed 63 packages in 775ms
#  + avro==1.11.3
#  + boto3==1.36.23
#  + botocore==1.36.23
#  + catboost==1.2
#  + comm==0.2.2
#  + confluent-kafka==2.3.0
#  + fastavro==1.8.4
#  + furl==2.1.3
#  - google-auth-oauthlib==1.2.1
#  + google-auth-oauthlib==1.0.0
#  + hopsworks==4.1.8
#  + hopsworks-aiomysql==0.2.1
#  - huggingface-hub==0.28.1
#  + huggingface-hub==0.24.7
#  - importlib-metadata==8.6.1
#  + importlib-metadata==6.11.0
#  - ipykernel==6.17.1
#  + ipykernel==6.29.5
#  + javaobj-py3==0.4.4
#  + jedi==0.19.2
#  + jmespath==1.0.1
#  - keras==3.8.0
#  + keras==2.14.0
#  - langchain==0.3.18
#  + langchain==0.2.6
#  - langchain-core==0.3.35
#  + langchain-core==0.2.43
#  + langchain-openai==0.1.14
#  - langchain-text-splitters==0.3.6
#  + langchain-text-splitters==0.2.4
#  - langsmith==0.3.8
#  + langsmith==0.1.147
#  + loguru==0.7.3
#  - ml-dtypes==0.4.1
#  + ml-dtypes==0.2.0
#  + mock==5.1.0
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + opensearch-py==2.4.2
#  + orderedmultidict==1.0.1
#  - packaging==24.2
#  + packaging==23.2
#  - pandas==2.2.2
#  + pandas==2.1.4
#  - pillow==11.1.0
#  + pillow==10.4.0
#  + pycryptodomex==3.21.0
#  + pydantic-settings==2.7.1
#  + pydeck==0.9.1
#  + pyhumps==1.6.1
#  + pyjks==20.0.0
#  + pymysql==1.1.1
#  + python-dotenv==1.0.1
#  + retrying==1.3.4
#  + s3transfer==0.11.2
#  - sentence-transformers==3.4.1
#  + sentence-transformers==2.2.2
#  - sqlalchemy==2.0.38
#  + sqlalchemy==2.0.29
#  + streamlit==1.28.2
#  - tenacity==9.0.0
#  + tenacity==8.5.0
#  - tensorboard==2.18.0
#  + tensorboard==2.14.1
#  - tensorflow==2.18.0
#  + tensorflow==2.14.0
#  + tensorflow-estimator==2.14.0
#  + tensorflow-recommenders==0.7.2
#  + tiktoken==0.9.0
#  + twofish==0.3.0
#  + validators==0.34.0
#  + watchdog==6.0.0
#  - wrapt==1.17.2
#  + wrapt==1.14.1
# ⛳️ Google Colab environment
# Adding the following directory to the PYTHONPATH: /content/hands-on-recommender-system

# %% [markdown]
# # 👩🏻‍🔬 Offline inference pipeline: Computing item embeddings
#
# In this notebook you will compute the candidate embeddings and populate a Hopsworks feature group with a vector index.

# %% [markdown]
# ## 📝 Imports

# %%
import warnings

warnings.filterwarnings("ignore")

from loguru import logger

from recsys import features, hopsworks_integration
from recsys.config import settings

# %% [markdown]
# ## Constants

# %%
from pprint import pprint

pprint(dict(settings))
# Out:
# {'CUSTOMER_DATA_SIZE': <CustomerDatasetSize.SMALL: 'SMALL'>,
#  'CUSTOM_HOPSWORKS_INFERENCE_ENV': 'custom_env_name',
#  'FEATURES_EMBEDDING_MODEL_ID': 'all-MiniLM-L6-v2',
#  'HOPSWORKS_API_KEY': None,
#  'OPENAI_API_KEY': None,
#  'OPENAI_MODEL_ID': 'gpt-4o-mini',
#  'RANKING_DATASET_VALIDATON_SPLIT_SIZE': 0.1,
#  'RANKING_EARLY_STOPPING_ROUNDS': 5,
#  'RANKING_ITERATIONS': 100,
#  'RANKING_LEARNING_RATE': 0.2,
#  'RANKING_MODEL_TYPE': 'ranking',
#  'RANKING_SCALE_POS_WEIGHT': 10,
#  'RECSYS_DIR': PosixPath('/content/hands-on-recommender-system/recsys'),
#  'TWO_TOWER_DATASET_TEST_SPLIT_SIZE': 0.1,
#  'TWO_TOWER_DATASET_VALIDATON_SPLIT_SIZE': 0.1,
#  'TWO_TOWER_LEARNING_RATE': 0.01,
#  'TWO_TOWER_MODEL_BATCH_SIZE': 2048,
#  'TWO_TOWER_MODEL_EMBEDDING_SIZE': 16,
#  'TWO_TOWER_NUM_EPOCHS': 10,
#  'TWO_TOWER_WEIGHT_DECAY': 0.001}

# %% [markdown]
# ## <span style="color:#ff5f27">🔮 Connect to Hopsworks Feature Store </span>

# %%
project, fs = hopsworks_integration.get_feature_store()

mr = project.get_model_registry()
# Out:
# 2025-02-19 03:55:26.858 | INFO     | recsys.hopsworks_integration.feature_store:get_feature_store:18 - Login to Hopsworks using cached API key.
# Copy your Api Key (first register/login): https://c.app.hopsworks.ai/account/api/generated
#
# Paste it here: ··········
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1213603

# %% [markdown]
# # Computing candidate embeddings
#
# You start by computing candidate embeddings for all items in the training data.
#
# First, you load your candidate model. Recall that you uploaded it to the Hopsworks Model Registry in previous steps:

# %%
candidate_model, candidate_features = (
    hopsworks_integration.two_tower_serving.HopsworksCandidateModel.download(mr=mr)
)
# Out:
# 2025-02-19 03:55:44.526 | INFO     | recsys.hopsworks_integration.two_tower_serving:download:185 - Downloading 'candidate_model' version 1

# %% [markdown]
# ### Get candidates data

# %% [markdown]
# Now, we get the training retrieval data containing all the features required for the candidate embedding model.

# %%
feature_view = fs.get_feature_view(
    name="retrieval",
    version=1,
)

# %%
train_df, val_df, test_df, _, _, _ = feature_view.train_validation_test_split(
    validation_size=settings.TWO_TOWER_DATASET_VALIDATON_SPLIT_SIZE,
    test_size=settings.TWO_TOWER_DATASET_TEST_SPLIT_SIZE,
    description="Retrieval dataset splits",
)
train_df.head(3)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (7.32s)
# VersionWarning: Incremented version to `2`.
#                                          customer_id article_id  t_dat  \
# 0  f7048acb8188d98bde3a5c495475a3c86faafe0eede1f2...  670265002      0
# 1  5d34f84e6cbe9ec4706872bb65376097af1e53f0c7dac5...  751471035      0
# 2  baf6dc7ea8575732794751bb80824fe84fd40e6af86193...  719308002      0
#
#       price     month_sin  month_cos   age club_member_status age_group  \
# 0  0.013542 -8.660254e-01   0.500000  48.0             ACTIVE     46-55
# 1  0.033881  1.224647e-16  -1.000000  30.0             ACTIVE     26-35
# 2  0.059305  5.000000e-01  -0.866025  48.0             ACTIVE     46-55
#
#   garment_group_name index_group_name
# 0  Under-, Nightwear       Ladieswear
# 1           Trousers       Ladieswear
# 2     Dresses Ladies          Divided

# %% [markdown]
# ### Compute embeddings
#
# Next you compute the embeddings of all candidate items that were used to train the retrieval model.

# %%
item_df = features.embeddings.preprocess(train_df, candidate_features)
item_df.head(3)
# Out:
#   garment_group_name article_id index_group_name
# 0  Under-, Nightwear  670265002       Ladieswear
# 1           Trousers  751471035       Ladieswear
# 2     Dresses Ladies  719308002          Divided

# %%
embeddings_df = features.embeddings.embed(df=item_df, candidate_model=candidate_model)
embeddings_df.head()
# Out:
#    article_id                                         embeddings
# 0   670265002  [-0.7604751586914062, 0.9238709807395935, -1.0...
# 1   751471035  [1.6406099796295166, 1.3932268619537354, 0.028...
# 2   719308002  [0.7188986539840698, 0.34544265270233154, -0.5...
# 3   759231002  [1.7318897247314453, 0.47544997930526733, -0.9...
# 4   733027006  [1.732801079750061, 0.2029293179512024, -0.809...

# %% [markdown]
# # <span style="color:#ff5f27">Create Hopsworks Embedding Index </span>
#
# Now you are ready to create a feature group for your candidate embeddings.
#
# To begin with, you need to create your Embedding Index where you will specify the name of the embeddings feature and the embeddings length.
# Then you attach this index to the FG.

# %%
candidate_embeddings_fg = (
    hopsworks_integration.feature_store.create_candidate_embeddings_feature_group(
        fs=fs, df=embeddings_df, online_enabled=True
    )
)
logger.info("✅ Uploaded 'candidate_embeddings' Feature Group to Hopsworks!!")
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1213603/fs/1201233/fg/1401277
# Uploading Dataframe: 100.00% |██████████| Rows 11824/11824 | Elapsed Time: 00:03 | Remaining Time: 00:00
# Launching job: candidate_embeddings_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1213603/jobs/named/candidate_embeddings_1_offline_fg_materialization/executions
# 2025-02-19 03:58:49.970 | INFO     | __main__:<cell line: 0>:6 - ✅ Uploaded 'candidate_embeddings' Feature Group to Hopsworks!!

# %% [markdown]
# ## Expose it to the online inference pipeline as a Feature View

# %%
feature_view = (
    hopsworks_integration.feature_store.create_candidate_embeddings_feature_view(
        fs=fs, fg=candidate_embeddings_fg
    )
)
# Out:
# Feature view created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/1213603/fs/1201233/fv/candidate_embeddings/version/1

# %% [markdown]
# ## <span style="color:#ff5f27"> Inspecting the embeddings in Hopsworks UI </span>
#
# View results in [Hopsworks Serverless](https://rebrand.ly/serverless-github): **Feature Store → Feature Groups**

# %% [markdown]
# ---

# %%
notebook_end_time = time.time()
notebook_execution_time = notebook_end_time - notebook_start_time

logger.info(
    f"⌛️ Notebook Execution time: {notebook_execution_time:.2f} seconds ~ {notebook_execution_time / 60:.2f} minutes"
)
# Out:
# 2025-02-19 03:59:37.091 | INFO     | __main__:<cell line: 0>:4 - ⌛️ Notebook Execution time: 357.80 seconds ~ 5.96 minutes

# %% [markdown]
# # <span style="color:#ff5f27">→ Next Steps </span>
#
# Now that we have our vector index populated with item embeddings, everything is ready for production. In the next notebook, we will zoom in into the inference pipeline and how we can deploy it to Hopsworks as a real-time deployment.
